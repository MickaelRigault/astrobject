# %%
import warnings
warnings.filterwarnings('ignore')
from astrobject.simulation import transient_generator

# %%
gen = transient_generator([0.01,0.1],ratekind="basic")
gen.show_skycoverage()
# Out:
# {'ax': <matplotlib.projections.geo.MollweideAxes at 0x108995f50>,
#  'figure': <matplotlib.figure.Figure at 0x108995550>,
#  'plot': [<matplotlib.lines.Line2D at 0x1089e55d0>]}

# %%
gen = transient_generator(300, (0.03, 0.08), ra_range=(-120, 60), dec_range=(-20, 60))
gen.show_skycoverage()
# Out:
# {'ax': <matplotlib.projections.geo.MollweideAxes at 0x7f151d78c850>,
#  'figure': <matplotlib.figure.Figure at 0x7f151db6f590>,
#  'plot': [<matplotlib.lines.Line2D at 0x7f151db28210>]}

# %%
gen.show_skycoverage(cscale='redshift')
# Out:
# {'ax': <matplotlib.projections.geo.MollweideAxes at 0x7f151c4baf50>,
#  'cbar': <matplotlib.colorbar.Colorbar at 0x7f151c141990>,
#  'figure': <matplotlib.figure.Figure at 0x7f151c20cd90>,
#  'plot': <matplotlib.collections.PathCollection at 0x7f151c08fa90>}

# %%
gen.show_skycoverage(cscale=range(300), cblabel='Whatever')
# Out:
# {'ax': <matplotlib.projections.geo.MollweideAxes at 0x7f151c2d94d0>,
#  'cbar': <matplotlib.colorbar.Colorbar at 0x7f151778c690>,
#  'figure': <matplotlib.figure.Figure at 0x7f151c4bf3d0>,
#  'plot': <matplotlib.collections.PathCollection at 0x7f15177f9190>}
